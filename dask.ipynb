# %%
from dask.distributed import Client

# %%
c = Client()
# Out:
# 2024-11-25 08:59:06,628 - tornado.application - ERROR - Exception in callback <bound method SystemMonitor.update of <SystemMonitor: cpu: 9 memory: 187 MB fds: 162>>
# Traceback (most recent call last):
#   File "/Users/chris.marais/.asdf/installs/python/3.12.2/lib/python3.12/site-packages/tornado/ioloop.py", line 937, in _run
#     val = self.callback()
#           ^^^^^^^^^^^^^^^
#   File "/Users/chris.marais/.asdf/installs/python/3.12.2/lib/python3.12/site-packages/distributed/system_monitor.py", line 168, in update
#     net_ioc = psutil.net_io_counters()
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/chris.marais/.asdf/installs/python/3.12.2/lib/python3.12/site-packages/psutil/__init__.py", line 2160, in net_io_counters
#     rawdict = _psplatform.net_io_counters()
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# OSError: [Errno 12] Cannot allocate memory

# %%
c
# Out:
# <Client: 'tcp://127.0.0.1:51598' processes=4 threads=12, memory=36.00 GiB>
